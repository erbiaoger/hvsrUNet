# %%
# !nvidia-smi
# Out:
# Thu Oct  5 11:15:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.48.07    Driver Version: 515.48.07    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:D8:00.0 Off |                  N/A |
# |  0%   31C    P8    21W / 370W |   4066MiB / 10240MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2893      G   /usr/lib/xorg/Xorg                 75MiB |
# |    0   N/A  N/A   3316824      C   ...user/anaconda3/bin/python     3987MiB |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow.keras import callbacks, optimizers, losses
from keras import backend as K
from sklearn.model_selection import train_test_split
import seaborn as sns
import string
import pandas as pd
from rich import print
import pathlib
from scipy import io as sio

from hvsrUNet.module.GPRNet import GPRNet
from hvsrUNet.toolbox.smooth import smooth

# %%
path_dir = pathlib.Path('../data/')
cv_list = sio.loadmat(path_dir/'cv_list.mat')['cv_list']
model_list = sio.loadmat(path_dir/'model_list_success.mat')['model_list_success']
fks = sio.loadmat(path_dir/'fks.mat')['fks']
fks = fks.reshape(-1)
hzcum = sio.loadmat(path_dir/'hzcum.mat')['hzcum']
hzcum = hzcum.reshape(-1)
print(f'cv_list.shape: {cv_list.shape}')
print(f'model_list.shape: {model_list.shape}')
print(f'fks.shape: {fks.shape}')
print(f'hzcum.shape: {hzcum.shape}')

disp = cv_list
Vs = model_list
# Out:
# cv_list.shape: (1200, 512)
# model_list.shape: (1200, 512)
# fks.shape: (512,)
# hzcum.shape: (512,)

# %%
disp    = np.expand_dims(disp, axis=-1) / 1000.
Vs      = np.expand_dims(Vs, axis=-1) / 1000.

X_train, X_test, y_train, y_test = train_test_split(disp, Vs, test_size=0.2, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
plt.plot(cv)

# %%
# %matplotlib inline
i = 3

cv      = disp[i] * 1000
vs1      = Vs[i] * 1000

with plt.style.context(['ggplot']):
    fig = plt.figure(figsize=(10, 6))
    ax1 = fig.add_subplot(121)
    ax1.plot(fks, cv, color='red', label='True', linewidth=2.5)
    ax1.set_ylim([50, 200])
    ax1.set_xlabel('frequence [Hz]')
    ax1.set_ylabel('velocity [m/s]')
    ax1.grid(True)
    ax2 = fig.add_subplot(122)
    ax2.plot(vs1, hzcum, color='blue', label='True', linewidth=2.5)
    ax2.set_xlim([50, 300])
    # ax.set_ylim([0, 100])
    ax2.invert_yaxis()
    ax2.set_xlabel('velocity [m/s]')
    ax2.set_ylabel('depth [m]')
    ax2.grid(True)

# %%
X_train = tf.expand_dims(X_train, axis=2)
y_train = tf.expand_dims(y_train, axis=2)
X_valid = tf.expand_dims(X_valid, axis=2)
y_valid = tf.expand_dims(y_valid, axis=2)
X_test = tf.expand_dims(X_test, axis=2)
y_test = tf.expand_dims(y_test, axis=2)


X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_valid.shape, y_valid.shape
# Out:
# (TensorShape([768, 512, 1, 1]),
#  TensorShape([768, 512, 1, 1]),
#  TensorShape([240, 512, 1, 1]),
#  TensorShape([240, 512, 1, 1]),
#  TensorShape([192, 512, 1, 1]),
#  TensorShape([192, 512, 1, 1]))

# %%
np.random.seed(33)
with plt.style.context('ggplot'):
    sns.set_theme(style=None)
    fig, axes = plt.subplots(1, 3, figsize=(8, 8))
    
    for j, ax in enumerate(axes.flat):
        i = np.random.randint(0, 10)

        ax.plot(np.squeeze(y_test[i, ...])*1000, hzcum, color='blue', label='True', linewidth=2.5)
        ax.set_title('Velocity profile')
        ax.set_xlabel('velocity (m/s)')
        ax.legend()
        ax.text(-0.1, 1.04, '('+string.ascii_lowercase[j]+')', transform=ax.transAxes, size=10, weight='bold')
        ax.xaxis.tick_top()
        ax.invert_yaxis()
    axes[0].set_ylabel('Depth (m)')
    fig.tight_layout()
    plt.show()

# %%
np.random.seed(33)
with plt.style.context('ggplot'):
    sns.set_theme(style=None)
    fig, axes = plt.subplots(3, 1, figsize=(8, 8))
    
    for j, ax in enumerate(axes.flat):
        i = np.random.randint(0, 10)

        ax.plot(fks, np.squeeze(X_test[i, ...])*1000, color='blue', label='True', linewidth=2.5)

        ax.set_xlabel('T [s]')
        ax.legend()
        ax.text(-0.1, 1.04, '('+string.ascii_lowercase[j]+')', transform=ax.transAxes, size=10, weight='bold')

    fig.tight_layout()
    plt.show()

# %%
model = GPRNet(im_width=1, im_height=512, neurons=8, kern_sz=10,enable_dropout=False)
# model.summary()
# model.load_weights('checkpoints/all_34/Weights/00540.keras')
# model_depth.load_weights('checkpoints/all_34/Weights/disp_depth_00540.keras')

# %%
name_checkpoint = 'checkpoints/2023_10_04/Weights/{epoch:04d}.keras' # 保存模型的路径。
log_dir = 'checkpoints/2023_10_04/Logs' # 日志文件保存的目录。
name_csv = 'checkpoints/2023_10_04/Logs/disp.csv' # 将被写入的文件的路径，例如：csv_logger(filename='training.log')。
lr_val = 0.0001
batch_size = 32
epochs = 1000
n_batches = len(X_train) / batch_size
n_batches = int(np.ceil(n_batches))

def R2_score(v_true, v_pred):
    ssres = K.sum(K.square(v_true - v_pred))
    sstot = K.sum(K.square(v_true - K.mean(v_true)))
    return 1 - ssres / sstot

model_checkpoint = callbacks.ModelCheckpoint(name_checkpoint, # 保存模型的路径。
                                #monitor='val_loss',         # 监控的数据。
                                monitor='val_R2_score',
                                verbose=0,                  # 日志显示模式，0或1。
                                save_best_only=False,       # True，那么最近验证误差最低的模型就不会被覆盖。
                                save_weights_only=False,    # True，那么只有模型的权重会被保存。
                                #mode='auto',                # {auto, min, max}的其中之一。
                                mode='max',
                                save_freq=10*n_batches)               # 'epoch'或整数。保存频率。

early_stopping = callbacks.EarlyStopping(monitor='val_loss', # 监控的数据。
                                min_delta=0,                    # 增大或减小的阈值，只有大于这个部分才算作improvement。
                                patience=100,                     # 没有进步的训练轮数，在这之后训练就会被停止。
                                verbose=0,                      # 日志显示模式，0或1。
                                mode='auto',                    # {auto, min, max}的其中之一。
                                baseline=None,                  # 要监控的数量的基准值，如果模型没有显示出基准的改善，则训练将停止。
                                restore_best_weights=False)     # 是否从具有监视器数量的最佳值的时期恢复模型权重。如果为False，则使用在训练的最后一步获得的模型权重。

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', # 监控的数据。
                                factor=0.5,                     # 触发时将学习率乘以系数的因数。
                                patience=15,                    # 没有进步的训练轮数，在这之后训练速率会被降低。
                                verbose=0,                      # 整数。0：安静，1：更新信息。
                                mode='auto',                    # {auto, min, max}的其中之一。
                                min_delta=0.000001,               # 对于测量新阈值的阈值，只关注巨大的变化。
                                cooldown=0,                     # 在lr被降低之后，训练将在cooldown内的epoch之后继续。
                                min_lr=0)                       # 学习率的下边界。

csv_logger = callbacks.CSVLogger(name_csv, # 将被写入的文件的路径，例如：csv_logger(filename='training.log')。
                                separator=',',              # 用于隔开值的字符串。
                                append=False)               # 如果为True，则将数据添加到现有文件中，而不会重新启动。

optimizer = optimizers.Adam(learning_rate=lr_val)
loss = losses.MeanSquaredError()
model.compile(optimizer=optimizer, loss=loss, metrics=['mae', 'mse', R2_score])

history = model.fit(X_train, y_train,
          validation_data=[X_valid,y_valid],
                  epochs=epochs,
                   batch_size=batch_size,
                   callbacks=[model_checkpoint, early_stopping, reduce_lr, csv_logger],
                   verbose=1)
# Out:
# Epoch 1/1000
# 24/24 [==============================] - 6s 42ms/step - loss: 0.0242 - mae: 0.1425 - mse: 0.0242 - R2_score: -11.3258 - val_loss: 0.0028 - val_mae: 0.0429 - val_mse: 0.0028 - val_R2_score: -0.3905 - lr: 1.0000e-04
# Epoch 2/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0035 - mae: 0.0468 - mse: 0.0035 - R2_score: -0.7950 - val_loss: 0.0021 - val_mae: 0.0374 - val_mse: 0.0021 - val_R2_score: -0.0385 - lr: 1.0000e-04
# Epoch 3/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0018 - mae: 0.0346 - mse: 0.0018 - R2_score: 0.0608 - val_loss: 0.0017 - val_mae: 0.0338 - val_mse: 0.0017 - val_R2_score: 0.1384 - lr: 1.0000e-04
# Epoch 4/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0015 - mae: 0.0315 - mse: 0.0015 - R2_score: 0.2135 - val_loss: 0.0015 - val_mae: 0.0321 - val_mse: 0.0015 - val_R2_score: 0.2235 - lr: 1.0000e-04
# Epoch 5/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0014 - mae: 0.0304 - mse: 0.0014 - R2_score: 0.2801 - val_loss: 0.0014 - val_mae: 0.0312 - val_mse: 0.0014 - val_R2_score: 0.2854 - lr: 1.0000e-04
# Epoch 6/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0013 - mae: 0.0297 - mse: 0.0013 - R2_score: 0.3259 - val_loss: 0.0013 - val_mae: 0.0302 - val_mse: 0.0013 - val_R2_score: 0.3405 - lr: 1.0000e-04
# Epoch 7/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0012 - mae: 0.0291 - mse: 0.0012 - R2_score: 0.3676 - val_loss: 0.0012 - val_mae: 0.0295 - val_mse: 0.0012 - val_R2_score: 0.3764 - lr: 1.0000e-04
# Epoch 8/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0012 - mae: 0.0284 - mse: 0.0012 - R2_score: 0.4046 - val_loss: 0.0012 - val_mae: 0.0289 - val_mse: 0.0012 - val_R2_score: 0.4059 - lr: 1.0000e-04
# Epoch 9/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0011 - mae: 0.0283 - mse: 0.0011 - R2_score: 0.4177 - val_loss: 0.0012 - val_mae: 0.0288 - val_mse: 0.0012 - val_R2_score: 0.4169 - lr: 1.0000e-04
# Epoch 10/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0011 - mae: 0.0281 - mse: 0.0011 - R2_score: 0.4308 - val_loss: 0.0012 - val_mae: 0.0286 - val_mse: 0.0012 - val_R2_score: 0.4211 - lr: 1.0000e-04
# Epoch 11/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0011 - mae: 0.0277 - mse: 0.0011 - R2_score: 0.4465 - val_loss: 0.0011 - val_mae: 0.0281 - val_mse: 0.0011 - val_R2_score: 0.4420 - lr: 1.0000e-04
# Epoch 12/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0011 - mae: 0.0281 - mse: 0.0011 - R2_score: 0.4338 - val_loss: 0.0012 - val_mae: 0.0287 - val_mse: 0.0012 - val_R2_score: 0.4039 - lr: 1.0000e-04
# Epoch 13/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0011 - mae: 0.0278 - mse: 0.0011 - R2_score: 0.4426 - val_loss: 0.0011 - val_mae: 0.0277 - val_mse: 0.0011 - val_R2_score: 0.4674 - lr: 1.0000e-04
# Epoch 14/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0011 - mae: 0.0275 - mse: 0.0011 - R2_score: 0.4601 - val_loss: 0.0012 - val_mae: 0.0285 - val_mse: 0.0012 - val_R2_score: 0.4046 - lr: 1.0000e-04
# Epoch 15/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0011 - mae: 0.0282 - mse: 0.0011 - R2_score: 0.4167 - val_loss: 0.0010 - val_mae: 0.0277 - val_mse: 0.0010 - val_R2_score: 0.4713 - lr: 1.0000e-04
# Epoch 16/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0010 - mae: 0.0275 - mse: 0.0010 - R2_score: 0.4666 - val_loss: 0.0010 - val_mae: 0.0275 - val_mse: 0.0010 - val_R2_score: 0.4713 - lr: 1.0000e-04
# Epoch 17/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0010 - mae: 0.0275 - mse: 0.0010 - R2_score: 0.4710 - val_loss: 0.0010 - val_mae: 0.0274 - val_mse: 0.0010 - val_R2_score: 0.4869 - lr: 1.0000e-04
# Epoch 18/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0010 - mae: 0.0273 - mse: 0.0010 - R2_score: 0.4844 - val_loss: 0.0010 - val_mae: 0.0273 - val_mse: 0.0010 - val_R2_score: 0.4809 - lr: 1.0000e-04
# Epoch 19/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0010 - mae: 0.0275 - mse: 0.0010 - R2_score: 0.4644 - val_loss: 0.0010 - val_mae: 0.0272 - val_mse: 0.0010 - val_R2_score: 0.4800 - lr: 1.0000e-04
# Epoch 20/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0010 - mae: 0.0273 - mse: 0.0010 - R2_score: 0.4622 - val_loss: 0.0010 - val_mae: 0.0270 - val_mse: 0.0010 - val_R2_score: 0.4884 - lr: 1.0000e-04
# Epoch 21/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0010 - mae: 0.0272 - mse: 0.0010 - R2_score: 0.4847 - val_loss: 9.7287e-04 - val_mae: 0.0268 - val_mse: 9.7287e-04 - val_R2_score: 0.5103 - lr: 1.0000e-04
# Epoch 22/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0010 - mae: 0.0271 - mse: 0.0010 - R2_score: 0.4881 - val_loss: 0.0010 - val_mae: 0.0268 - val_mse: 0.0010 - val_R2_score: 0.4790 - lr: 1.0000e-04
# Epoch 23/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 9.9416e-04 - mae: 0.0269 - mse: 9.9416e-04 - R2_score: 0.4944 - val_loss: 0.0010 - val_mae: 0.0266 - val_mse: 0.0010 - val_R2_score: 0.4926 - lr: 1.0000e-04
# Epoch 24/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0010 - mae: 0.0270 - mse: 0.0010 - R2_score: 0.4845 - val_loss: 0.0010 - val_mae: 0.0266 - val_mse: 0.0010 - val_R2_score: 0.4964 - lr: 1.0000e-04
# Epoch 25/1000
# 24/24 [==============================] - 0s 20ms/step - loss: 9.9589e-04 - mae: 0.0264 - mse: 9.9589e-04 - R2_score: 0.4932 - val_loss: 0.0010 - val_mae: 0.0267 - val_mse: 0.0010 - val_R2_score: 0.4760 - lr: 1.0000e-04
# Epoch 26/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 9.8059e-04 - mae: 0.0264 - mse: 9.8059e-04 - R2_score: 0.5002 - val_loss: 9.3472e-04 - val_mae: 0.0260 - val_mse: 9.3472e-04 - val_R2_score: 0.5297 - lr: 1.0000e-04
# Epoch 27/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 9.3623e-04 - mae: 0.0259 - mse: 9.3623e-04 - R2_score: 0.5189 - val_loss: 9.2965e-04 - val_mae: 0.0258 - val_mse: 9.2965e-04 - val_R2_score: 0.5323 - lr: 1.0000e-04
# Epoch 28/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 9.0318e-04 - mae: 0.0256 - mse: 9.0318e-04 - R2_score: 0.5417 - val_loss: 8.6651e-04 - val_mae: 0.0251 - val_mse: 8.6651e-04 - val_R2_score: 0.5639 - lr: 1.0000e-04
# Epoch 29/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 8.7963e-04 - mae: 0.0251 - mse: 8.7963e-04 - R2_score: 0.5487 - val_loss: 8.3339e-04 - val_mae: 0.0246 - val_mse: 8.3339e-04 - val_R2_score: 0.5807 - lr: 1.0000e-04
# Epoch 30/1000
# 24/24 [==============================] - 1s 28ms/step - loss: 8.5096e-04 - mae: 0.0247 - mse: 8.5096e-04 - R2_score: 0.5634 - val_loss: 8.0350e-04 - val_mae: 0.0241 - val_mse: 8.0350e-04 - val_R2_score: 0.5957 - lr: 1.0000e-04
# Epoch 31/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 8.0154e-04 - mae: 0.0240 - mse: 8.0154e-04 - R2_score: 0.5941 - val_loss: 7.5279e-04 - val_mae: 0.0232 - val_mse: 7.5279e-04 - val_R2_score: 0.6213 - lr: 1.0000e-04
# Epoch 32/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 7.3981e-04 - mae: 0.0229 - mse: 7.3981e-04 - R2_score: 0.6236 - val_loss: 6.7820e-04 - val_mae: 0.0218 - val_mse: 6.7820e-04 - val_R2_score: 0.6589 - lr: 1.0000e-04
# Epoch 33/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 6.6853e-04 - mae: 0.0216 - mse: 6.6853e-04 - R2_score: 0.6616 - val_loss: 6.2353e-04 - val_mae: 0.0208 - val_mse: 6.2353e-04 - val_R2_score: 0.6862 - lr: 1.0000e-04
# Epoch 34/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 5.9210e-04 - mae: 0.0200 - mse: 5.9210e-04 - R2_score: 0.6993 - val_loss: 5.3467e-04 - val_mae: 0.0190 - val_mse: 5.3467e-04 - val_R2_score: 0.7310 - lr: 1.0000e-04
# Epoch 35/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 5.2488e-04 - mae: 0.0186 - mse: 5.2488e-04 - R2_score: 0.7299 - val_loss: 4.9167e-04 - val_mae: 0.0175 - val_mse: 4.9167e-04 - val_R2_score: 0.7526 - lr: 1.0000e-04
# Epoch 36/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 4.7050e-04 - mae: 0.0173 - mse: 4.7050e-04 - R2_score: 0.7595 - val_loss: 5.1152e-04 - val_mae: 0.0185 - val_mse: 5.1152e-04 - val_R2_score: 0.7423 - lr: 1.0000e-04
# Epoch 37/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 4.3163e-04 - mae: 0.0164 - mse: 4.3163e-04 - R2_score: 0.7791 - val_loss: 3.9593e-04 - val_mae: 0.0155 - val_mse: 3.9593e-04 - val_R2_score: 0.8006 - lr: 1.0000e-04
# Epoch 38/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 3.9136e-04 - mae: 0.0153 - mse: 3.9136e-04 - R2_score: 0.8002 - val_loss: 3.6883e-04 - val_mae: 0.0147 - val_mse: 3.6883e-04 - val_R2_score: 0.8142 - lr: 1.0000e-04
# Epoch 39/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 3.8659e-04 - mae: 0.0151 - mse: 3.8659e-04 - R2_score: 0.8019 - val_loss: 3.7560e-04 - val_mae: 0.0145 - val_mse: 3.7560e-04 - val_R2_score: 0.8108 - lr: 1.0000e-04
# Epoch 40/1000
# 24/24 [==============================] - 1s 29ms/step - loss: 3.7656e-04 - mae: 0.0147 - mse: 3.7656e-04 - R2_score: 0.8093 - val_loss: 4.4744e-04 - val_mae: 0.0155 - val_mse: 4.4744e-04 - val_R2_score: 0.7747 - lr: 1.0000e-04
# Epoch 41/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 3.5593e-04 - mae: 0.0143 - mse: 3.5593e-04 - R2_score: 0.8181 - val_loss: 3.2528e-04 - val_mae: 0.0136 - val_mse: 3.2528e-04 - val_R2_score: 0.8361 - lr: 1.0000e-04
# Epoch 42/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 3.2731e-04 - mae: 0.0135 - mse: 3.2731e-04 - R2_score: 0.8344 - val_loss: 3.5303e-04 - val_mae: 0.0136 - val_mse: 3.5303e-04 - val_R2_score: 0.8222 - lr: 1.0000e-04
# Epoch 43/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 3.5497e-04 - mae: 0.0141 - mse: 3.5497e-04 - R2_score: 0.8194 - val_loss: 3.9689e-04 - val_mae: 0.0163 - val_mse: 3.9689e-04 - val_R2_score: 0.8000 - lr: 1.0000e-04
# Epoch 44/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 3.1837e-04 - mae: 0.0132 - mse: 3.1837e-04 - R2_score: 0.8356 - val_loss: 2.9446e-04 - val_mae: 0.0125 - val_mse: 2.9446e-04 - val_R2_score: 0.8516 - lr: 1.0000e-04
# Epoch 45/1000
# 24/24 [==============================] - 1s 25ms/step - loss: 3.0214e-04 - mae: 0.0128 - mse: 3.0214e-04 - R2_score: 0.8469 - val_loss: 3.1474e-04 - val_mae: 0.0138 - val_mse: 3.1474e-04 - val_R2_score: 0.8414 - lr: 1.0000e-04
# Epoch 46/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 2.8502e-04 - mae: 0.0124 - mse: 2.8502e-04 - R2_score: 0.8560 - val_loss: 2.8849e-04 - val_mae: 0.0130 - val_mse: 2.8849e-04 - val_R2_score: 0.8546 - lr: 1.0000e-04
# Epoch 47/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 2.8568e-04 - mae: 0.0125 - mse: 2.8568e-04 - R2_score: 0.8533 - val_loss: 2.9375e-04 - val_mae: 0.0120 - val_mse: 2.9375e-04 - val_R2_score: 0.8520 - lr: 1.0000e-04
# Epoch 48/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 2.9431e-04 - mae: 0.0126 - mse: 2.9431e-04 - R2_score: 0.8469 - val_loss: 2.7557e-04 - val_mae: 0.0125 - val_mse: 2.7557e-04 - val_R2_score: 0.8611 - lr: 1.0000e-04
# Epoch 49/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 2.5014e-04 - mae: 0.0114 - mse: 2.5014e-04 - R2_score: 0.8729 - val_loss: 2.5301e-04 - val_mae: 0.0116 - val_mse: 2.5301e-04 - val_R2_score: 0.8725 - lr: 1.0000e-04
# Epoch 50/1000
# 24/24 [==============================] - 1s 27ms/step - loss: 2.4703e-04 - mae: 0.0112 - mse: 2.4703e-04 - R2_score: 0.8736 - val_loss: 2.4371e-04 - val_mae: 0.0110 - val_mse: 2.4371e-04 - val_R2_score: 0.8772 - lr: 1.0000e-04
# Epoch 51/1000
# 24/24 [==============================] - 1s 23ms/step - loss: 2.3688e-04 - mae: 0.0108 - mse: 2.3688e-04 - R2_score: 0.8803 - val_loss: 2.3884e-04 - val_mae: 0.0111 - val_mse: 2.3884e-04 - val_R2_score: 0.8796 - lr: 1.0000e-04
# Epoch 52/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 2.2758e-04 - mae: 0.0105 - mse: 2.2758e-04 - R2_score: 0.8853 - val_loss: 2.3355e-04 - val_mae: 0.0107 - val_mse: 2.3355e-04 - val_R2_score: 0.8823 - lr: 1.0000e-04
# Epoch 53/1000
# 24/24 [==============================] - 1s 24ms/step - loss: 2.2924e-04 - mae: 0.0107 - mse: 2.2924e-04 - R2_score: 0.8820 - val_loss: 2.4430e-04 - val_mae: 0.0116 - val_mse: 2.4430e-04 - val_R2_score: 0.8769 - lr: 1.0000e-04
# Epoch 54/1000
# 24/24 [==============================] - 1s 21ms/step - loss: 2.2166e-04 - mae: 0.0105 - mse: 2.2166e-04 - R2_score: 0.8862 - val_loss: 2.2121e-04 - val_mae: 0.0103 - val_mse: 2.2121e-04 - val_R2_score: 0.8885 - lr: 1.0000e-04
# Epoch 55/1000
# 24/24 [==============================] - 0s 21ms/step - loss: 2.2086e-04 - mae: 0.0103 - mse: 2.2086e-04 - R2_score: 0.8870 - val_loss: 2.4470e-04 - val_mae: 0.0116 - val_mse: 2.4470e-04 - val_R2_score: 0.8767 - lr: 1.0000e-04
# Epoch 56/1000
# 24/24 [==============================] - 1s 21ms/step - loss: 2.1304e-04 - mae: 0.0102 - mse: 2.1304e-04 - R2_score: 0.8917 - val_loss: 2.1579e-04 - val_mae: 0.0104 - val_mse: 2.1579e-04 - val_R2_score: 0.8912 - lr: 1.0000e-04
# Epoch 57/1000
# 24/24 [==============================] - 1s 21ms/step - loss: 2.0141e-04 - mae: 0.0097 - mse: 2.0141e-04 - R2_score: 0.8969 - val_loss: 2.1896e-04 - val_mae: 0.0100 - val_mse: 2.1896e-04 - val_R2_score: 0.8896 - lr: 1.0000e-04
# Epoch 58/1000
# 24/24 [==============================] - 1s 22ms/step - loss: 1.9776e-04 - mae: 0.0095 - mse: 1.9776e-04 - R2_score: 0.9001 - val_loss: 2.0626e-04 - val_mae: 0.0100 - val_mse: 2.0626e-04 - val_R2_score: 0.8960 - lr: 1.0000e-04
# Epoch 59/1000
# 11/24 [============>.................] - ETA: 0s - loss: 1.9114e-04 - mae: 0.0094 - mse: 1.9114e-04 - R2_score: 0.9017

# %%
X_test.shape, y_test.shape, yy_test.shape
# Out:
# (TensorShape([1494, 512, 1]),
#  TensorShape([1494, 512, 1]),
#  TensorShape([1494, 1, 1]))

# %%
training_log = pd.read_csv('checkpoints/2023_10_04/Logs/disp.csv')
training_log.head()

mse_loss = training_log['loss']
val_mse_loss = training_log['val_loss']
acc = training_log['R2_score']
val_acc = training_log['val_R2_score']

accu = {'mse_loss': mse_loss, 
        'val_mse_loss': val_mse_loss,
        'acc': acc,
        'val_acc': val_acc}

value = [mse_loss, val_mse_loss, acc, val_acc]
name = ['mse_loss', 'val_mse_loss', 'acc', 'val_acc']

epochs = range(1, len(acc) + 1)

with plt.style.context('ggplot'):
    sns.set_theme(style='darkgrid')
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))

    for i, ax in enumerate(axes):

        ax.plot(epochs, value[2*i], label=name[2*i], marker='o', color='blue', markevery=50)
        ax.plot(epochs, value[2*i+1], label=name[2*i+1], color='red')
        ax.set_yscale('log')
        ax.set_xlabel('Epochs')
        ax.legend()
        #ax.set_title(name)
    
    plt.tight_layout()

plt.show()

# %%
ypred = model.predict(X_test[:100, ...])

#ypred = model.predict(X_train)

# %%
with plt.style.context('ggplot'):
    sns.set_theme(style=None)
    fig, axes = plt.subplots(1, 3, figsize=(8, 8))
    
    for j, ax in enumerate(axes.flat):
        i = np.random.randint(0, 10)

        yy = smooth(np.squeeze(ypred[i, ...]), window_len=10, window='blackman')
        depth = np.linspace(hzcum[i].min(), hzcum[i].max(), len(yy))

        ax.plot(yy*1000, depth, color='red', label='Prediction', linewidth=2.5)
        ax.plot(np.squeeze(y_test[i, ...])*1000, hzcum[i], color='blue', label='True', linewidth=2.5)
        ax.set_title('Prediction')
        ax.set_xlabel('velocity (m/s)')
        ax.legend()
        ax.text(-0.1, 1.04, '('+string.ascii_lowercase[j]+')', transform=ax.transAxes, size=10, weight='bold')
        ax.xaxis.tick_top()
        ax.invert_yaxis()
    axes[0].set_ylabel('Depth (m)')
    fig.tight_layout()
    plt.show()
